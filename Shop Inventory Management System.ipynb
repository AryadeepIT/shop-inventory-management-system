# %% [markdown]
# ### Product Details
# 1. Product ID
# 2. Name of Product
# 3. Price of Product
# 4. Quantity

# %%
# Noting the time of transaction
import time


# Reading the Inventory
fd = open('Inventory.txt','r')
products = fd.read().split('\n')
fd.close()

# Showing Inventory Availibility to user
print("----------------------------------")
print("Available Product Details : ")
print("----------------------------------")
print("pid:name:₹:qty")
for product in products:
    print(product)
print("----------------------------------")

# Taking input from the user
ui_username  = input("Enter your UserName: ")
ui_phone     = input("Enter your Phone Number: ")
ui_mail      = input("Enter your Mail: ")
ui_prod_id   = input("Enter Product ID: ")
ui_prod_qn   = input("Enter Product Quantity: ")

updated_product_lst = []

# Going through each product details
for product in products:
    
    prod_details = product.split(',')
    
    if(prod_details[0] == ui_prod_id):
    # Checking if product exists or not        
        
        if (int(ui_prod_qn) <= int(prod_details[3])):
        # If product's quantity available
            print("-----------------------------")
            print("Product Name     : ", prod_details[1])
            print("Price            : ", prod_details[2]) 
            print("Quantity         : ", ui_prod_qn) 
            print("-----------------------------")
            print("Billing Amount   : ", int(ui_prod_qn) * int(prod_details[2]))
            print("-----------------------------")
            
            # Updating Inventory List
            prod_details[3] = str(int(prod_details[3]) - int(ui_prod_qn))
            
            # Generating Sales in Sales.txt
            fd = open("Sales.txt", 'a')
            sales_detail = ui_username + "," + ui_phone + "," + ui_mail + ","+ prod_details[1]+ "," + ui_prod_id + "," + ui_prod_qn + ","+str(int(ui_prod_qn) * int(prod_details[2]))+ "," + time.ctime() + "\n"
            fd.write(sales_detail)
            fd.close()
        else:
        # If don't have enough quantity
            print("--------------------------------------------------")
            print("Sorry, We're not having enough Quantity.")
            print("We're having only ",prod_details[3],'quantity.')
            print("Would you like to purchase it?")
            print("--------------------------------------------------")
            
            ch = input("Press Y/N ")
            
            if (ch=='Y' or ch=='y'):
            # If user want to purchase with remaining quantity
                print("-----------------------------")
                print("Product Name     : ", prod_details[1])
                print("Price            : ", prod_details[2]) 
                print("Quantity         : ", prod_details[3]) 
                print("-----------------------------")
                print("Billing Amount   : ", int(prod_details[3]) * int(prod_details[2]))
                print("-----------------------------")
                
                
                # Generating Sales in Sales.txt
                fd = open("Sales.txt", 'a')
                sales_detail = ui_username + "," + ui_phone + "," + ui_mail + ","+ prod_details[1]+ "," + ui_prod_id + "," + prod_details[3] + ","+str(int(prod_details[3]) * int(prod_details[2]))+ "," + time.ctime() + "\n"
                fd.write(sales_detail)
                fd.close()
                
                # Updating Inventory List
                prod_details[3] = '0'
                
            else:
                print("Thanks")
                
    # Updating Inventory List   
    updated_product_lst.append(prod_details)
    

    
lst = []

# Updating Inventory String
for i in updated_product_lst:
    prod = i[0] +","+  i[1] +","+ i[2] +","+ i[3] + '\n'
    lst.append(prod)

# Removing last '\n' from file
lst[-1] = lst[-1][:-1]

# Updating Inventory File
fd = open('Inventory.txt','w')

for i in lst:
    fd.write(i)

fd.close()


print("----------------------------------")
print("Inventory Updated")
print("----------------------------------")
# Out:
# ----------------------------------
# Available Product Details :
# ----------------------------------
# pid:name:₹:qty
# 1,Modern Bread,17,50
# 2,Good Night Mosquito Refill,77,20
# 3,Amul Taaza Milk,26,50
# 4,Red Cow Milk,30,30
# 5,Metro Toned Fresh Milk,26,40
# 6,Thumps Up,36,10
# 7,Sprite,38,0
# 8,Limca,40,5
# 9,Fanta,50,4
# 10,Mountain Dew,40,8
# 11,Bisleri Packaged Water,65,3
# 12,Bisleri Water,20,10
# 13,Lays Chips,20,50
# 14,Kurkure Chips,20,48
# 15,Uncle Chipps,20,30
# 16,Doritos,30,10
# 17,Bingo Chips,35,10
# 18,ACT II popcorn,10,30
# 19,Prabhuji Bhujia,247,5
# 20,Mukharochak Chanachur,70,10
# 21,Britannia Treat,20,15
# 22,Winkies Tea Cake,124,3
# 23,Britannia Toastea,40,5
# 24,Fortune Mustard Oil,154,10
# 25,Tata Salt,25,10
# ----------------------------------
# Enter your UserName: Chakraborty
# Enter your Phone Number: 9933744337
# Enter your Mail: chakraborty@chak.com
# Enter Product ID: 3
# Enter Product Quantity: 80
# --------------------------------------------------
# Sorry, We're not having enough Quantity.
# We're having only  50 quantity.
# Would you like to purchase it?
# --------------------------------------------------
# Press Y/N n
# Thanks
# ----------------------------------
# Inventory Updated
# ----------------------------------
